# %% [markdown]
# ## Introduccion a la estadistica
#
# ## estadistica
# Es una parte de la rama que nos permite entender a los datos, sus caracteristica:
# - Organizacion
# - Visualización
# - Interpretación
# - Análisis
#
# # Estadistica Descriptiva
# - Nos ayuda a generar nueva informacion a tráves de predicciones.
# - Interpretación de los datos / modelo de los datos.
#
# ## Análisis exploratorio  de los datos / Análisis descriptivo
# - Nos ayuda a interpretar patrones.
# - Visualización de como ser comportado por los datos.
#
# ## Tipos de datos
# - Cualitativos. Se describen por caracterusticas general. Catégoricos
# - Cuantitativos. Representa algo que se pueda contar.
#
#
# ### Estadistica Infernal
# - Nos ayudan a generar nueva informacion a traves de predicciones
# - Inteepretacion de los datos / modelo de los datos
#
# ## Analisis exploratorio de los datos / Analisis descriptivo
#
# ### Tipos de datos
# - Cualitativos. Se describen por caracteristicas generales. Categoricos
# - Cuantitativos. Representa algo que se puede contar
#
# ### Tipos de variables Tipos de Datos Cuantitativos
# Nominales: Los valores que permiten clasificar a una poblacion en categorias excluyentes.
# Ordinales: Valores que pueden ser ordenados.
# Discretos: Numero finito de valores.
# Continuos: Numero infinito de valores en un inventario.
#
# ## Organizacion y presentacion de los datos
# Tablas: SQL, NOSQL, Excel, CSV, API, JSON
#
# ### Librerias
# Pandas:
#
# - Manejo de datos.
# - Ofrece manejar los datos a traves de estructuras.
# - Manejo de matrices.
# - Formato.
# - Transformacion
# - Leer archivos
#
#
# maplotlib
# - Graficar
# - Diagramas
#
# Sklearn
# - Es una biblioteca de aprendizaje automatico gratitua
# - Tambien cuenta con algunas bases de datos

# %%
import pandas as pd
data = {'name':['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'year':[2012, 2012, 2013, 2014, 2014],
        'reports': [4, 24, 31, 2, 3]}
print(data)

df = pd.DataFrame(data)
print(df)

from sklearn.datasets import fetch_openml
titanic = fetch_openml('titanic', version=1, as_frame=True)
titanic_frame = pd.DataFrame(titanic.data)
titanic_frame
# Out:
# {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'year': [2012, 2012, 2013, 2014, 2014], 'reports': [4, 24, 31, 2, 3]}
#     name  year  reports
# 0  Jason  2012        4
# 1  Molly  2012       24
# 2   Tina  2013       31
# 3   Jake  2014        2
# 4    Amy  2014        3
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 10
#       7 df = pd.DataFrame(data)
#       8 print(df)
# ---> 10 from sklearn.datasets import fetch_openml
#      11 titanic = fetch_openml('titanic', version=1, as_frame=True)
#      12 titanic_frame = pd.DataFrame(titanic.data)
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Base de datos
#
# # Base de datos
# Entidades - tablas
# Atributos, Caracteristicas de las entidades
# El nombre de las Columnas
# Filas - registrps
# Valores - Cada uno de los datos que se representan por columna
#
# # Tablas
# columnas - Features
# Registros
#
# ## Tablas de Frecuencias
# Sirve para contar la informacion de acuerdo a una variable
#
#
#
# ## Tablas de contigencia
# Sirve para clasificar por n variables (dependiendo de como manejen la informacion)
#
#
#
# # Presentacion de Datos
#
# ## Graficas
# Nos permiten vizualizar la informacion y sus caracteristicas
# - Nos van a permitir representar 2 o 3 variables cualitativas y cuantitativas
#
# ### Tipos de graficas
# - Grafica de Barras
# - Grafica de sectores - pastel, circular
# - Grafica de dispersion
# - Histograma
# - Grafica de Lineas
# - Grafica box-plot o diagrama de cajas
#
# # Estadistica Descirptiva
# ## Medidas de Tendencia Central
# - Media
# - Mediana
# - Moda
# - Media geometrica
#
# ## Medias de Dispersion
# - Varianza
# - Desviacion Estandar
# - Coeficiente de variacion
#
# - Recorrido
# - Recorrido intercuantilico
# - Cuantiles - Cuartiles,
